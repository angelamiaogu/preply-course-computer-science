# %%
import pandas as pd
am = pd.read_csv('accelerometer.csv')
am = am.iloc[100:200,:]

# %%
# plot column x
import matplotlib.pyplot as plt
plt.plot(am['x'])

# %%
# plot y and z

plt.plot(am['y'])

# %%
plt.plot(am['z'])

# %%
plt.plot(am['x'])
plt.plot(am['y'])
plt.plot(am['z'])
