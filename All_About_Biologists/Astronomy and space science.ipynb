# %% [markdown]
# # angela is on Mars all alone and she has knowledge of python and Biology?

# %%
# angela is ran out of Food and she wants to make her own food on Mars

# %%
# how to make banana on marks

# %%
# suitable environment for banana tree
# a seed for banan
# water supply
# soil / waste of living bodies 
#

# %%
# in mars make a system of temperature controlling and by chance if there is any wrong temperature you will get alarm?

# %%
# make fuction which will take x argument
# if x<10 print ("ALAAAARMM!!!!!!!!!!!")
# if x<10 and less than 37 print("all normal")
# if x > 37 print ("ALAAARRRMM!!!!!!!!!!!")
import time
import random
def banana(x):
    if x < 10:
        print (x,"AAAAAAAAAH it's too cold!!!!!!!!!!!!")
        return -1
    elif x > 37:
        print (x,"AAAAAAAAAH it's too hot!!!!!!!!!!!")
        return -1
    else:
        print (x,"All notmal")
        return 0




# angela gang will come back mars in 30 days

def heater_on(x):
    time.sleep(0.1)
    x = x + 1
    return x
def heater_off(x):
    time.sleep(0.1)
    x = x - 1
    return x
# we create a simulation of 30 days
day = 0
room_temp = 20
while(day<31):
    day = day + 1
    print("day is",day)
    mar_temp = random.randint(1 ,40)
    room_temp= mar_temp

    while banana(room_temp)==-1 and banana(room_temp)!=0:
        room_temp = heater_on(room_temp)

    mar_temp = random.randint(5 ,40)
    room_temp= mar_temp
    while(banana(room_temp)==0) and banana(room_temp)!=-1:
        room_temp = heater_off(room_temp)

    


    day = day + 1
# Out:
# day is 1
# 20 All notmal
# 18 All notmal
# 18 All notmal
# 17 All notmal
# 17 All notmal
# 16 All notmal
# 16 All notmal
# 15 All notmal
# 15 All notmal
# 14 All notmal
# 14 All notmal
# 13 All notmal
# 13 All notmal
# 12 All notmal
# 12 All notmal
# 11 All notmal
# 11 All notmal
# 10 All notmal
# 10 All notmal
# 9 AAAAAAAAAH it's too cold!!!!!!!!!!!!
# day is 3
# 19 All notmal
# 12 All notmal
# 12 All notmal
# 11 All notmal
# 11 All notmal
# 10 All notmal
# 10 All notmal
# 9 AAAAAAAAAH it's too cold!!!!!!!!!!!!
# day is 5
# 17 All notmal
# 28 All notmal
# 28 All notmal
# 27 All notmal
# 27 All notmal
# 26 All notmal
# 26 All notmal
# 25 All notmal
# 25 All notmal
# 24 All notmal
# 24 All notmal
# 23 All notmal
# 23 All notmal
# 22 All notmal
# 22 All notmal
# 21 All notmal
# 21 All notmal
# 20 All notmal
# 20 All notmal
# 19 All notmal
# 19 All notmal
# 18 All notmal
# 18 All notmal
# 17 All notmal
# 17 All notmal
# 16 All notmal
# 16 All notmal
# 15 All notmal
# 15 All notmal
# ...

# %%
for i in range(10):
    print("MR UMAIR I'M BACK")
# Out:
# MR UMAIR I'M BACK
# MR UMAIR I'M BACK
# MR UMAIR I'M BACK
# MR UMAIR I'M BACK
# MR UMAIR I'M BACK
# MR UMAIR I'M BACK
# MR UMAIR I'M BACK
# MR UMAIR I'M BACK
# MR UMAIR I'M BACK
# MR UMAIR I'M BACK
