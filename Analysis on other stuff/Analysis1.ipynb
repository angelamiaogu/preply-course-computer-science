# %%
import pandas as pd
data = pd.read_csv('2021.csv')
data
# Out:
#         Unnamed: 0        id  year  mathematics_score  literature_score  \
# 0                0   1000046  2022                8.0              6.25
# 1                1   1000031  2022                7.0              7.75
# 2                2   1000012  2022                6.4              7.50
# 3                3   1000087  2022                8.4              8.00
# 4                4   1000071  2022                7.6              8.25
# ...            ...       ...   ...                ...               ...
# 995376      995376  64006555  2022                6.2              4.75
# 995377      995377  64006584  2022                8.4              6.75
# 995378      995378  64006576  2022                6.6              5.25
# 995379      995379  64006583  2022                5.0              6.50
# 995380      995380  64006581  2022                6.6              6.00
#
#         physics_score  chemistry_score  biology_score  foreign_language_score  \
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0            id      year  mathematics_score  \
# count  995381.000000  9.953810e+05  995381.0      982670.000000
# mean   497690.000000  2.759687e+07    2022.0           6.466307
# std    287341.888484  1.917116e+07       0.0           1.675402
# min         0.000000  1.000001e+06    2022.0           0.000000
# 25%    248845.000000  1.000216e+07    2022.0           5.400000
# 50%    497690.000000  2.801888e+07    2022.0           6.800000
# 75%    746535.000000  4.400583e+07    2022.0           7.800000
# max    995380.000000  6.400659e+07    2022.0          10.000000
#
#        literature_score  physics_score  chemistry_score  biology_score  \
# count     981351.000000  325510.000000    327353.000000  322185.000000
# mean           6.507771       6.723776         6.703872       5.019119
# std            1.379598       1.441914         1.600390       1.448270
# min            0.000000       0.000000         0.000000       0.000000
# ...

# %%
#using seabor boxplot for mathematical_score
import seaborn as sb
sb.boxplot(x = "literature_score",data = data)
# Out:
# <AxesSubplot:xlabel='literature_score'>

# %%
# you have to add a column of passAndFail, those makrs more than 5 they are pass
# those stuntn who has marks lesso htna 5 fail

# %%
new_data = data.iloc[:,1:13]
new_data
# Out:
#               id  year  mathematics_score  literature_score  physics_score  \
# 0        1000046  2022                8.0              6.25           7.25
# 1        1000031  2022                7.0              7.75            NaN
# 2        1000012  2022                6.4              7.50            NaN
# 3        1000087  2022                8.4              8.00            NaN
# 4        1000071  2022                7.6              8.25           6.25
# ...          ...   ...                ...               ...            ...
# 995376  64006555  2022                6.2              4.75            NaN
# 995377  64006584  2022                8.4              6.75            NaN
# 995378  64006576  2022                6.6              5.25            NaN
# 995379  64006583  2022                5.0              6.50            NaN
# 995380  64006581  2022                6.6              6.00            NaN
#
#         chemistry_score  biology_score  foreign_language_score  \
# ...

# %%
# add a new column and write nothing
new_data['result'] = 'nothing'
new_data
# Out:
#               id  year  mathematics_score  literature_score  physics_score  \
# 0        1000046  2022                8.0              6.25           7.25
# 1        1000031  2022                7.0              7.75            NaN
# 2        1000012  2022                6.4              7.50            NaN
# 3        1000087  2022                8.4              8.00            NaN
# 4        1000071  2022                7.6              8.25           6.25
# ...          ...   ...                ...               ...            ...
# 995376  64006555  2022                6.2              4.75            NaN
# 995377  64006584  2022                8.4              6.75            NaN
# 995378  64006576  2022                6.6              5.25            NaN
# 995379  64006583  2022                5.0              6.50            NaN
# 995380  64006581  2022                6.6              6.00            NaN
#
#         chemistry_score  biology_score  foreign_language_score  \
# ...

# %%
new_data['year'].unique()
# Out:
# array([2022])

# %%
del new_data['year']

# %%
x = ['biology_score','mathematics_score','literature_score','english_score','geography_score'] #

# %%
data = data[x]
data
# Out:
#         biology_score  mathematics_score  literature_score  english_score  \
# 0                4.75                8.0              6.25            4.6
# 1                 NaN                7.0              7.75            8.8
# 2                 NaN                6.4              7.50            NaN
# 3                 NaN                8.4              8.00            9.4
# 4                3.25                7.6              8.25            6.6
# ...               ...                ...               ...            ...
# 995376            NaN                6.2              4.75            2.8
# 995377            NaN                8.4              6.75            4.6
# 995378            NaN                6.6              5.25            3.2
# 995379            NaN                5.0              6.50            3.8
# 995380            NaN                6.6              6.00            4.2
#
#         geography_score
# 0                   NaN
# 1                  5.00
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,4) ,dpi = 300)
sb.boxplot(data=data)
# Out:
# <AxesSubplot:>
