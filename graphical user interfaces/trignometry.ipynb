# %%
import matplotlib.pyplot as plt
import numpy as np
x =  np.arange(0,2*np.pi,0.01)
y = 10*np.sin(x)
plt.plot(x, y)

# %%
x = np.arange(0,2*np.pi,0.01)
y = 6*np.sin(x)*np.cos(x)+ 3 * np.cos(x)+4*np.sin(x) +2
plt.plot(x,y)
