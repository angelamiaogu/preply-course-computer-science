# %%
# linear
# regression
# import numpy
import numpy as np
import matplotlib.pyplot as plt

# %%
# make a dictionary with keys as size and value as price and please write atleast 1 0 values

# %%
# write dictionary as size price thing
# rent a homte
# 1 room means 100 usd per night
# 2 room 190
dictionary = {1:100,2:190,3:280,4:370,5:460}

# %%
# make a numpy array with kkeys and values
k = dictionary.keys()
v = dictionary.values()

# %%
plt.plot(k,v,'x')

# %%
# y = mx + c
plt.plot(k,v,'x')
x=np.array([1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6,6.5])
m = 92
c = 0.01
y = m*x+c

plt.plot(x,y)

# %%
y = m*100+c
y
# Out:
# 9200.01
