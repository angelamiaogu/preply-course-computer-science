# %% [markdown]
# # what is a Neuron?
# 86_000_000_000 neurons are in human mind. All are interconnected. Each neuron has input(s) and  output(s)

# %%
# machine learning is based on it.

# %%
# the very basic building block of machine learning is a single neuron.

# %%
# what is intelligence?

# %%
# artificial intelligence

# %%
# is rules or algorithms which are defined by experts so machines can make decisions

# %%
# network is connection between 2 or many devices

# %%
# neurons connecting with each other, then it is called neural network

# %% [markdown]
# ### perceptron is a (simplest)neural network which connects neurons with each other

# %% [markdown]
# ![228C54D3-E797-4036-BA55-D7A50F954CB8.png](attachment:228C54D3-E797-4036-BA55-D7A50F954CB8.png)

# %% [markdown]
# ## The figure above is showing the perceptron which has a single input and output layer

# %% [markdown]
# ##WHAT HAPPENS INSIDE A NODE

# %%
x0 = 0 # input 1
x1 = 1 # input 2

w0 = 0.5 # weight 1
w1 = 0.5 # weight 2


out = (x0 * w0) + (x1 * w1)

#thres = 0.4 # or gate
thres = 0.6
print(out)
print((out>thres)*1) # apply threshold of 0.4

# change the input and see which logic gate is this
# Out:
# 0.5
# 0

# %% [markdown]
# ![9AD274A2-014F-4DF1-B282-4FD4D632AB23.png](attachment:9AD274A2-014F-4DF1-B282-4FD4D632AB23.png)
