# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Plot the generated data
plt.scatter(X, y)
plt.title('Synthetic Data for Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# Linear regression cost function (Mean Squared Error)
def cost_function(theta, X, y):
    m = len(y)
    predictions = X.dot(theta)
    error = predictions - y
    cost = (1/(2*m)) * np.sum(error**2)
    return cost

# Gradient descent function
def gradient_descent(X, y, theta, learning_rate, iterations):
    m = len(y)
    cost_history = []

    for _ in range(iterations):
        predictions = X.dot(theta)
        errors = predictions - y
        gradient = (1/m) * X.T.dot(errors)
        theta = theta - learning_rate * gradient
        cost = cost_function(theta, X, y)
        cost_history.append(cost)

    return theta, cost_history

# Add bias term to the input data
X_b = np.c_[np.ones((len(X), 1)), X]

# Initialize theta with random values
theta_initial = np.random.rand(2, 1)

# Set hyperparameters
learning_rate = 0.01
iterations = 1000

# Run gradient descent
theta_optimal, cost_history = gradient_descent(X_b, y, theta_initial, learning_rate, iterations)

# Print the optimal parameters
print("Optimal Parameters (Theta):", theta_optimal)

# Plot the cost history
plt.plot(cost_history)
plt.title('Cost Function History during Gradient Descent')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.show()

# Plot the linear regression line on the data
plt.scatter(X, y, label='Data')
plt.plot(X, X_b.dot(theta_optimal), color='red', label='Linear Regression')
plt.title('Linear Regression with Gradient Descent')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Optimal Parameters (Theta): [[4.06929893]
#  [2.89884441]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Linear regression cost function (Mean Squared Error)
def cost_function(theta, X, y):
    m = len(y)
    predictions = X.dot(theta)
    error = predictions - y
    cost = (1/(2*m)) * np.sum(error**2)
    return cost

# Gradient descent function
def gradient_descent(X, y, theta, learning_rate, iterations):
    m = len(y)
    cost_history = []

    for _ in range(iterations):
        predictions = X.dot(theta)
        errors = predictions - y
        gradient = (1/m) * X.T.dot(errors)
        theta = theta - learning_rate * gradient
        cost = cost_function(theta, X, y)
        cost_history.append(cost)

    return theta, cost_history

# Add bias term to the input data
X_b = np.c_[np.ones((len(X), 1)), X]

# Initialize theta with random values
theta_initial = np.random.rand(2, 1)

# Set hyperparameters
learning_rate = 0.01
iterations = 1000

# Run gradient descent
theta_optimal, cost_history = gradient_descent(X_b, y, theta_initial, learning_rate, iterations)

# Plot the linear regression line on the data
plt.figure(figsize=(12, 4))

# Plot 1: Scatter plot of data points
plt.subplot(1, 3, 1)
plt.scatter(X, y)
plt.title('Synthetic Data for Linear Regression')
plt.xlabel('X')
plt.ylabel('y')

# Plot 2: Cost function history
plt.subplot(1, 3, 2)
plt.plot(cost_history)
plt.title('Cost Function History during Gradient Descent')
plt.xlabel('Iteration')
plt.ylabel('Cost')

# Plot 3: Linear regression line on the data
plt.subplot(1, 3, 3)
plt.scatter(X, y, label='Data')
plt.plot(X, X_b.dot(theta_optimal), color='red', label='Linear Regression')
plt.title('Linear Regression with Gradient Descent')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# a plate with 3 spoons always moving

# %%
# just 1 minute
