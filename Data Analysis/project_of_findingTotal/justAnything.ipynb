# %% [markdown]
# ####  please load csv file in python usign pandas

# %%
import pandas as pd
data_main = pd.read_csv("FX_29feb2024_Internal_sorted.csv")
data = data_main.copy()

# %% [markdown]
# ### there is something wrong in

# %% [markdown]
# # using groupby please groupbye data based on counterparty and find sum?????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????????

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Counterparty       500 non-null    object
#  1   Instrument         500 non-null    object
#  2   USDSpots           500 non-null    object
#  3   USDFwdsSwapsTotal  500 non-null    object
#  4   USDSpotRank        500 non-null    object
#  5   USDFwdsSwapsRank   500 non-null    object
# dtypes: object(6)
# memory usage: 23.6+ KB

# %%
data.groupby("Counterparty").sum() # please angela focurs, write .sum! i am telling my mouth is owwhh
# Out:
#                                                      Instrument  \
# Counterparty
# ANZFX                      AUDUSDEURUSDNZDUSDUSDCADUSDCHFUSDJPY
# BARCCAP       AUDUSDEURCZKEURGBPEURHUFEURNOKEURPLNEURSEKEURU...
# BNPFX         AUDUSDEURCZKEURHUFEURNOKEURPLNEURSEKEURUSDGBPU...
# BOAMLFX       AUDUSDEURCZKEURHUFEURNOKEURPLNEURSEKEURUSDGBPU...
# CITI          AUDUSDEURCZKEURGBPEURHUFEURNOKEURPLNEURSEKEURU...
# COMMFX        AUDUSDEURHUFEURNOKEURPLNEURSEKEURUSDGBPUSDNZDU...
# Counterparty  InstrumentInstrumentInstrumentInstrumentInstru...
# DEBK          AUDUSDEURHUFEURNOKEURPLNEURSEKEURUSDGBPUSDNZDU...
# EDGEW         AUDUSDEURCZKEURGBPEURHUFEURNOKEURPLNEURSEKEURU...
# GDML          AUDUSDEURCZKEURGBPEURHUFEURNOKEURPLNEURSEKEURU...
# HSBCFX               EURUSDUSDIDRUSDINRUSDPHPUSDTHBUSDTWDUSDZAR
# JPML          AUDUSDEURUSDGBPUSDUSDBRLUSDCADUSDCHFUSDCNHUSDC...
# MSI           AUDUSDEURCZKEURGBPEURHUFEURNOKEURPLNEURSEKEURU...
# ...

# %%
data.columns
# Out:
# Index(['Counterparty', 'Instrument', 'USDSpots', 'USDFwdsSwapsTotal',
#        'USDSpotRank', 'USDFwdsSwapsRank'],
#       dtype='object')

# %%
columns_to_convert = ['Counterparty', 'Instrument', 'USDSpots', 'USDFwdsSwapsTotal',
       'USDSpotRank', 'USDFwdsSwapsRank']
data[columns_to_convert] = data[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
data.iloc[:,:2] = data_main.iloc[:,:2].copy()

# %%
data
# Out:
#     Counterparty Instrument    USDSpots  USDFwdsSwapsTotal  USDSpotRank  \
# 0          ANZFX     AUDUSD  52673639.0                0.0         13.0
# 1          ANZFX     EURUSD  29022792.0                0.0         15.0
# 2          ANZFX     NZDUSD   9200601.0                0.0         14.0
# 3          ANZFX     USDCAD   8000000.0                0.0         15.0
# 4          ANZFX     USDCHF  23130000.0                0.0         14.0
# ..           ...        ...         ...                ...          ...
# 495          XTX     USDJPY  74050000.0                0.0          9.0
# 496          XTX     USDMXN  71890000.0                0.0          1.0
# 497          XTX     USDSGD  19590000.0                0.0          8.0
# 498          XTX     USDTHB   7440000.0                0.0          5.0
# 499          XTX     USDZAR  12526000.0                0.0          6.0
#
#      USDFwdsSwapsRank
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Counterparty       500 non-null    object
#  1   Instrument         500 non-null    object
#  2   USDSpots           468 non-null    float64
#  3   USDFwdsSwapsTotal  468 non-null    float64
#  4   USDSpotRank        468 non-null    float64
#  5   USDFwdsSwapsRank   468 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 23.6+ KB

# %%
data.groupby("Counterparty").sum()
# Out:
#                   USDSpots  USDFwdsSwapsTotal  USDSpotRank  USDFwdsSwapsRank
# Counterparty
# ANZFX         1.422470e+08       0.000000e+00         84.0               0.0
# BARCCAP       1.019525e+09       3.526638e+08         36.0             177.0
# BNPFX         2.675691e+08       5.007690e+08        132.0             171.0
# BOAMLFX       7.685878e+08       1.094853e+09        136.0             214.0
# CITI          1.313125e+09       1.022448e+09         95.0             131.0
# COMMFX        6.461157e+08       1.675215e+08        141.0              56.0
# Counterparty  0.000000e+00       0.000000e+00          0.0               0.0
# DEBK          1.893321e+08       3.221120e+08        162.0              45.0
# EDGEW         5.560175e+08       0.000000e+00        135.0               0.0
# GDML          1.658975e+09       2.471395e+09         88.0             177.0
# HSBCFX        0.000000e+00       2.414433e+07          0.0              68.0
# ...

# %%
# make bar plot of data
data['USDSpots'].plot(kind = "bar",rot=180)
# Out:
# <AxesSubplot:>
