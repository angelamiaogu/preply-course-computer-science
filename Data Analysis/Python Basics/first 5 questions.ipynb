# %% [markdown]
# Class Initialization:
#
# Create a class named Dog with an __init__ method that initializes attributes for the dog's name and breed.
#
# Method Addition:
# Add a method to the Dog class called bark that prints a message like "Woof! Woof!".
# Method Parameter:
#
# Modify the bark method to take an additional parameter called times and adjust the message to repeat the barking sound based on the value of times.
#
# Class Inheritance:
# Create a subclass of the Dog class called Poodle that includes an additional attribute for the poodle's hair type (e.g., curly or straight).
#
# Method Override:
# Override the bark method in the Poodle class to include information about the poodle's hair type in the barking message.
# Instance Creation:

# %%
class dog:
    def ___init___(self, name, breed):
        self.name = name
        self.breed = breed

# %% [markdown]
# Create an empty dictionary called my_dict.
# Key-Value Addition:
#
# Add a key-value pair to my_dict where the key is "fruit" and the value is "apple".
# Key Check:
#
# Check if the key "fruit" exists in my_dict. Print "Key exists" if it does, otherwise print "Key does not exist".
# Value Retrieval:
#
# Retrieve and print the value associated with the key "fruit" from my_dict.
# Key Deletion:
#
# Remove the key "fruit" from my_dict.
# Default Value Retrieval:
#
# Use the get method to retrieve the value for the key "fruit" from my_dict. Print "Key not found" if the key is not present.
# Key-Value Modification:
#
# Change the value associated with the key "fruit" to "banana" in my_dict.
# Dictionary Keys:
#
# Print all the keys in my_dict.
# Dictionary Values:
#
# Print all the values in my_dict.
# Dictionary Length:
#
# Print the number of key-value pairs in my_dict.

# %%
my_dict = {"fruit":"apple"}

if "fruit" in my_dict:
    print(my_dict)
else:
    print("not here")
# Out:
# {'fruit': 'apple'}

# %%
import pandas as pd

# %%
data = pd.read_excel("/Users/angelasthingy/Desktop/preply-course-computer-science/Data Analysis/Chapter 3 Numpy and Pandas/banana.xlsx")
data
# Out:
#   Unnamed: 0  arfa  banana  andy  angela
# 0     Sunday    96       5    90      11
# 1     Monday    69      62    26      14
# 2    Tuesday    64      64    45      50
# 3  Wednesday    11      17    69      47
# 4   Thursday    36      66    88      29
# 5     Friday    82      22    24       7
# 6   Saturday    28      44    26      40

# %%
data.plot()
# Out:
# <AxesSubplot:>
