# %%
import pandas as pd
data = pd.read_excel("sample-input-file.xlsx")
data.head(5)
# Out:
# /Users/angelasthingy/opt/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                         Keyword  westfallsellers.com  versustexas.com  \
# 0            tdcj inmate search                    0               10
# 1                bac calculator                    0               40
# 2                       fake id                    0               25
# 3                    public sex                    0               37
# 4  tarrant county inmate search                    0               14
#
#    Search Volume  Keyword Difficulty   CPC  Competition     Results  \
# 0         201000                  69  0.53          0.0      677000
# 1         135000                  68  1.06          0.0    14500000
# 2          74000                  55  0.00          0.0  1510000000
# ...

# %%
data['seo'] = data["westfallsellers.com"] + data["versustexas.com"]

# %%
data
# Out:
#                                   Keyword  westfallsellers.com  \
# 0                      tdcj inmate search                    0
# 1                          bac calculator                    0
# 2                                 fake id                    0
# 3                              public sex                    0
# 4            tarrant county inmate search                    0
# ...                                   ...                  ...
# 27332  youngest age of consent in america                    0
# 27333   youngest age of consent in the us                    0
# 27334         youngest person to have sex                    0
# 27335                     youth diversion                    0
# 27336      zero point offender adjustment                    0
#
#        versustexas.com  Search Volume  Keyword Difficulty   CPC  Competition  \
# 0                   10         201000                  69  0.53          0.0
# ...

# %%
data.pivot_table(index='versustexas.com (pages)',values='seo',aggfunc='sum')
# Out:
#                                                      seo
# versustexas.com (pages)
# https://dallas.versustexas.com/                     1396
# https://dallas.versustexas.com/assault-family-v...   386
# https://dallas.versustexas.com/beat-dallas-assa...    14
# https://dallas.versustexas.com/bipp-classes-in-...   358
# https://dallas.versustexas.com/contact-us/            55
# ...                                                  ...
# https://versustexas.com/wp-content/uploads/2017...   345
# https://versustexas.com/wp-content/uploads/2017...   145
# https://versustexas.com/wp-content/uploads/2020...    84
# https://versustexas.com/wp-content/uploads/2020...  3232
# https://versustexas.com/wp-content/uploads/2022...   131
#
# [511 rows x 1 columns]
