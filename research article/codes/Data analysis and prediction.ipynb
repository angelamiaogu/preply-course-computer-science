# %%
import pandas as pd
data = pd.read_csv('/Users/angelasthingy/Desktop/preply-course-computer-science/research article/data/Data1/heart_attack_prediction_dataset.csv')
data
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       BMW7812   67    Male          208         158/88          72
# 1       CZE1114   21    Male          389         165/93          98
# 2       BNI9906   21  Female          324         174/99          72
# 3       JLN3497   84    Male          383        163/100          73
# 4       GFO8847   66    Male          318          91/88          93
# ...         ...  ...     ...          ...            ...         ...
# 8758    MSV9918   60    Male          121          94/76          61
# 8759    QSV6764   28  Female          120        157/102          73
# 8760    XKA5925   47    Male          250         161/75         105
# 8761    EPE6801   36    Male          178         119/67          60
# 8762    ZWN9666   25  Female          356         138/67          75
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# 0            0               0        1        0  ...
# ...

# %%
import seaborn as sns
sns.countplot(x = 'Heart Attack Risk', data = data)
# Out:
# <AxesSubplot:xlabel='Heart Attack Risk', ylabel='count'>

# %%
sns.countplot(x = 'Heart Attack Risk', data = data,hue='Sex')
# Out:
# <AxesSubplot:xlabel='Heart Attack Risk', ylabel='count'>

# %%
dha = data[data['Heart Attack Risk']==1]

# %%
sns.countplot(x = 'Sex', data = dha)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# What is the main research question or problem addressed in this paper, and why is it important?
# Ans:
# tey are using weak algorithm together to get better result
#
#
#
# Briefly describe the methods used in the study. How do these methods help in answering the research question?
# SVM,NAive bayesian, RF,
#
# What are the key findings or results of the research? Were there any unexpected outcomes?
#
#
# How do the authors interpret their findings in the discussion section? Do they acknowledge any limitations of their study?
#
# What conclusions do the authors draw, and how do these conclusions contribute to the field of study or to practical applications?
