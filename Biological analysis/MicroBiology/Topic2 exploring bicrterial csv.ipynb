# %%
import pandas as pd
data = pd.read_csv("microbes.csv")

# %%
data.describe()
# Out:
#         Unnamed: 0      Solidity  Eccentricity  EquivDiameter       Extrema  \
# count  30527.00000  30527.000000  30527.000000   30527.000000  30527.000000
# mean   15263.00000      9.677744     19.466921       3.633348     11.871832
# std     8812.53017      4.063437      3.479828       2.210851      6.045135
# min        0.00000      0.000000      0.000000       0.000000      0.000000
# 25%     7631.50000      6.570000     17.300000       2.180000      6.790000
# 50%    15263.00000      9.350000     20.700000       3.380000     12.000000
# 75%    22894.50000     12.600000     22.200000       4.580000     17.200000
# max    30526.00000     23.000000     23.000000      23.000000     23.000000
#
#          FilledArea        Extent   Orientation   EulerNumber  BoundingBox1  \
# count  30527.000000  30527.000000  30527.000000  30527.000000  30527.000000
# mean       0.420022      5.840625     11.751004     22.380901     10.919027
# ...

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'Solidity', 'Eccentricity', 'EquivDiameter', 'Extrema',
#        'FilledArea', 'Extent', 'Orientation', 'EulerNumber', 'BoundingBox1',
#        'BoundingBox2', 'BoundingBox3', 'BoundingBox4', 'ConvexHull1',
#        'ConvexHull2', 'ConvexHull3', 'ConvexHull4', 'MajorAxisLength',
#        'MinorAxisLength', 'Perimeter', 'ConvexArea', 'Centroid1', 'Centroid2',
#        'Area', 'raddi', 'microorganisms'],
#       dtype='object')

# %%
keyS = list(data.columns)[1:]

# %%
keyS
# Out:
# ['Solidity',
#  'Eccentricity',
#  'EquivDiameter',
#  'Extrema',
#  'FilledArea',
#  'Extent',
#  'Orientation',
#  'EulerNumber',
#  'BoundingBox1',
#  'BoundingBox2',
#  'BoundingBox3',
#  'BoundingBox4',
#  'ConvexHull1',
#  'ConvexHull2',
#  'ConvexHull3',
#  'ConvexHull4',
#  'MajorAxisLength',
#  'MinorAxisLength',
#  'Perimeter',
#  'ConvexArea',
#  'Centroid1',
#  'Centroid2',
#  'Area',
#  'raddi',
#  'microorganisms']

# %%
{
    'Solidity': 'Solidity is a measure of the compactness of a shape, calculated as the ratio of the object\'s area to the area of its convex hull.',
    'Eccentricity': 'Eccentricity describes how much an ellipse deviates from being a perfect circle.',
    'EquivDiameter': 'Equivalent Diameter is the diameter of a circle with the same area as the object.',
    'Extrema': 'Extrema are the outermost points of an object in different directions.',
    'FilledArea': 'Filled Area represents the total number of pixels inside the object\'s boundary.',
    'Extent': 'Extent is the ratio of the object\'s area to the area of the bounding box.',
    'Orientation': 'Orientation refers to the angle at which the major axis of the object is oriented.',
    'EulerNumber': 'Euler Number is a topological invariant that describes the number of objects in an image minus the number of holes in those objects.',
    'BoundingBox1': 'Bounding Box 1 represents the x-coordinate of the left edge of the bounding box.',
    'BoundingBox2': 'Bounding Box 2 represents the y-coordinate of the top edge of the bounding box.',
    'BoundingBox3': 'Bounding Box 3 represents the width of the bounding box.',
    'BoundingBox4': 'Bounding Box 4 represents the height of the bounding box.',
    'ConvexHull1': 'Convex Hull 1 represents the x-coordinate of the first point in the convex hull.',
    'ConvexHull2': 'Convex Hull 2 represents the y-coordinate of the first point in the convex hull.',
    'ConvexHull3': 'Convex Hull 3 represents the x-coordinate of the last point in the convex hull.',
    'ConvexHull4': 'Convex Hull 4 represents the y-coordinate of the last point in the convex hull.',
    'MajorAxisLength': 'Major Axis Length is the length of the longest line segment that can be drawn inside the object and is parallel to the major axis.',
    'MinorAxisLength': 'Minor Axis Length is the length of the longest line segment that can be drawn inside the object and is perpendicular to the major axis.',
    'Perimeter': 'Perimeter is the total length of the object\'s boundary.',
    'ConvexArea': 'Convex Area represents the total number of pixels inside the convex hull of the object.',
    'Centroid1': 'Centroid 1 represents the x-coordinate of the object\'s centroid, which is the center of mass.',
    'Centroid2': 'Centroid 2 represents the y-coordinate of the object\'s centroid.',
    'Area': 'Area represents the total number of pixels inside the object\'s boundary.',
    'raddi': 'Raddi could be a specific term or acronym related to a particular context. Please provide more information for a precise definition.',
    'microorganisms': 'Microorganisms are tiny living organisms, such as bacteria, viruses, fungi, and protozoa, that are not visible to the naked eye and can only be seen under a microscope.'
}
# Out:
# {'Solidity': "Solidity is a measure of the compactness of a shape, calculated as the ratio of the object's area to the area of its convex hull.",
#  'Eccentricity': 'Eccentricity describes how much an ellipse deviates from being a perfect circle.',
#  'EquivDiameter': 'Equivalent Diameter is the diameter of a circle with the same area as the object.',
#  'Extrema': 'Extrema are the outermost points of an object in different directions.',
#  'FilledArea': "Filled Area represents the total number of pixels inside the object's boundary.",
#  'Extent': "Extent is the ratio of the object's area to the area of the bounding box.",
#  'Orientation': 'Orientation refers to the angle at which the major axis of the object is oriented.',
#  'EulerNumber': 'Euler Number is a topological invariant that describes the number of objects in an image minus the number of holes in those objects.',
#  'BoundingBox1': 'Bounding Box 1 represents the x-coordinate of the left edge of the bounding box.',
# ...
