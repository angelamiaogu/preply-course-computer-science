# %%
import seaborn as sb
import pandas as pd
data = pd.read_csv('Redbull.csv')
data
# Out:
#      Volunteer_ID     sex agegrp  bp_before  bp_after  Unnamed: 5
# 0               1    Male  30-45        143       153         NaN
# 1               2    Male  30-45        163       170         NaN
# 2               3    Male  30-45        153       168         NaN
# 3               4    Male  30-45        153       168         NaN
# 4               5    Male  30-45        146       161         NaN
# ..            ...     ...    ...        ...       ...         ...
# 115           116  Female    60+        152       152         NaN
# 116           117  Female    60+        161       177         NaN
# 117           118  Female    60+        165       174         NaN
# 118           119  Female    60+        149       151         NaN
# 119           120  Female    60+        185       204         NaN
#
# [120 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Volunteer_ID  120 non-null    int64
#  1   sex           120 non-null    object
#  2   agegrp        120 non-null    object
#  3   bp_before     120 non-null    int64
#  4   bp_after      120 non-null    int64
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.8+ KB

# %%
data.describe()
# Out:
#        Volunteer_ID   bp_before    bp_after  Unnamed: 5
# count    120.000000  120.000000  120.000000         0.0
# mean      60.500000  156.450000  170.566667         NaN
# std       34.785054   11.389845   13.855032         NaN
# min        1.000000  138.000000  145.000000         NaN
# 25%       30.750000  147.000000  160.000000         NaN
# 50%       60.500000  154.500000  169.000000         NaN
# 75%       90.250000  164.000000  178.250000         NaN
# max      120.000000  185.000000  204.000000         NaN

# %%
data['bp_after']
# Out:
# 0      153
# 1      170
# 2      168
# 3      168
# 4      161
#       ...
# 115    152
# 116    177
# 117    174
# 118    151
# 119    204
# Name: bp_after, Length: 120, dtype: int64

# %%
# using seabron lets plot sb.linplot(data[['bp_before',bp_after]])
import matplotlib.pyplot as plt
plt.plot(data[['bp_before']])
plt.plot(data['bp_after'])
plt.legend(['BP BEFORE', 'BP AFTER'])

# %%
# data of bp for 1 person
data2 = pd.read_csv("personHeartbeat.csv")
data2
# Out:
#                  time_span  heartbeat
# 0      2021-07-13 18:52:19  91.324484
# 1      2021-07-13 18:52:20  90.813173
# 2      2021-07-13 18:52:21  88.886994
# 3      2021-07-13 18:52:22  89.957997
# 4      2021-07-13 18:52:23  91.501462
# ...                    ...        ...
# 73435  2021-07-14 15:16:14  88.159514
# 73436  2021-07-14 15:16:15  88.723643
# 73437  2021-07-14 15:16:16  88.101037
# 73438  2021-07-14 15:16:17  90.846451
# 73439  2021-07-14 15:16:18  90.442098
#
# [73440 rows x 2 columns]

# %%
hb = data2['heartbeat'][0:120]

# %%
plt.plot(hb)
# HW is find number of beats per minutes

# %%
# find number of peaks in 1 minite
import scipy
pks,*_ = scipy.signal.find_peaks(hb)
plt.plot(hb)
plt.plot(hb[pks],'x')
# it is 2 minutes.. cna you coun number of peaks 
len(pks)
# Out:
# 39

# %%
# above file was heartbeat itself!

# %%
# we actually have to count heart beats from ecg signal!
# download ECG signal ,, find peaks , plot htme,,, then then use len to find number of peaks

# %%
# task 1

import pandas as andy
data = andy.read_html('https://drive.google.com/file/d/1xEfv2YHAe1_F1OceVmNzenFPeXsCWBAl/view?usp=sharing')
data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/l_/j699flmx6dbc1vlb90jx_hyw0000gn/T/ipykernel_327/3015373612.py in <module>
#       2
#       3 import pandas as andy
# ----> 4 data = andy.read_html('https://drive.google.com/file/d/1xEfv2YHAe1_F1OceVmNzenFPeXsCWBAl/view?usp=sharing')
#       5 data
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111     io = stringify_path(io)
#    1112
# ...
