# %%
# 1. we have to download 10 pictures of bread and we have to keep them to a folder

# %%
# you have to use plt.imshow to show the picture of your most favourite breads from Breads folder

# %%
import matplotlib.pyplot as plt
img = plt.imread("Breads/anpan18.jpeg")
plt.imshow(img)

# %%
#show another image please

# %%
img2 = plt.imread("Breads/download (2).jpeg")
plt.imshow(img2)

# %%
# i can not upload all the images so how can i plot all the images at once

# %%
import os
lsts = list(os.walk('Breads'))
lsts
# Out:
# [('Breads',
#   [],
#   ['download.jpeg',
#    'download (3).jpeg',
#    'download (1).jpeg',
#    'milk-bread.webp',
#    'download (2).jpeg',
#    'anpan18.jpeg',
#    'Garlic-Bread-4.webp',
#    'hqdefault.jpeg',
#    'cinnamon-swirl-bread-recipe-1x1-1.jpeg'])]

# %%
# collect the list only from lsts using index for example lsts

# %%
need = lsts[0][2]

# %%
x = ['andy','angela']
print(x[1])
# Out:
# angela

# %%
x = [[],['andy','angela']]
print(x[1][1])
# Out:
# angela

# %%
x = ['andy',['angela'],'Mom']
print(x[2])
# Out:
# Mom

# %%
# runa  for loop over need lsit and plot all images one by one
n=1
plt.figure(figsize=(6,6),dpi=300)
for name in need:
    plt.subplot(3,3,n)
    img = plt.imread('Breads/'+name)
    plt.imshow(img)
    n = n+1
    plt.axis('off')
    plt.title('Angela')
plt.show()
