# %%
### make a list of 10 ages
age = [1,2,3,4,5,6,7,10,19,42]
ph_sc = [21,24,25,23,22,25,23,27,28,23]

result = [0,0,1,0,0,1,0,1,1,1]

# %%
import pandas as pd
data = {

    "age":age,
    "scores":ph_sc,
    "res":result

}
data

# %%
df = pd.DataFrame(data)
df

# %%
df.to_csv("final.csv" ,index=None)

# %%
df

# %%
import seaborn as sb
sb.scatterplot(x="age",y="scores",data = df)

# %%
sb.scatterplot(x="age",y="scores",data = df, hue = "res")

# %%
s= 42
ag = 24

if s > 24 or ag >42:
    print("yes present 1")
else:
    print("no present 0")

# %%
data = pd.read_csv("/Users/angelasthingy/Desktop/preply-course-computer-science/Data/Student Survey.csv")
data.columns
# Out:
# Index(['Unnamed: 0', 'How old are you?', 'How many Rodys do you own?',
#        'How tall are you?', 'How many siblings do you have?',
#        'What color is your hair?', 'How many years have you attended Aoba?'],
#       dtype='object')

# %%
sb.scatterplot(x = 'How many siblings do you have?', y ='How many Rodys do you own?',data = data, hue = 'How old are you?')
# Out:
# <AxesSubplot:xlabel='How many siblings do you have?', ylabel='How many Rodys do you own?'>

# %%
### load a data from internet and plot it using seaborn ... you can use hue or you cna not use hue ,,, its your choice

import pandas as pd
angela = pd.read_csv("/Users/angelasthingy/Desktop/preply-course-computer-science/Data/birthweight.csv")
angela
# Out:
#       id   headcirumference   length   Birthweight   Gestation   smoker  \
# 0   1313                 12       17           5.8          33        0
# 1    431                 12       19           4.2          33        1
# 2    808                 13       19           6.4          34        0
# 3    300                 12       18           4.5          35        1
# 4    516                 13       18           5.8          35        1
# 5    321                 13       19           6.8          37        0
# 6   1363                 12       19           5.2          37        1
# 7    575                 12       19           6.1          37        1
# 8    822                 13       19           7.5          38        0
# 9   1081                 14       21           8.0          38        0
# 10  1636                 14       20           8.6          38        0
# 11  1107                 14       20           7.1          38        0
# ...

# %%
data.columns
# Out:
# Index(['id', ' headcirumference', ' length', ' Birthweight', ' Gestation',
#        ' smoker', ' motherage', ' mnocig', ' mheight', ' mppwt', ' fage',
#        ' fedyrs', ' fnocig', ' fheight', ' lowbwt', ' mage35',
#        ' LowBirthWeight'],
#       dtype='object')

# %%
import seaborn as sb
sb.scatterplot(x = ' motherage'  , y = ' Birthweight', data = data, hue = ' LowBirthWeight', )
# Out:
# <AxesSubplot:xlabel=' motherage', ylabel=' Birthweight'>

# %%
import pandas as pa
angela_bb = pa.read_csv("/Users/angelasthingy/Desktop/preply-course-computer-science/Data/basketball.csv")
angela_bb
# Out:
#     ID  Name Position  Height  Weight  Sponsorship Earnings Shoe Sponsor  \
# 0    1  Adam  forward     192     218                   561          yes
# 1    2  Bill   center     218     251                    60           no
# 2    3  Clay  forward     197     221                  1312           no
# 3    4  Dale  forward     192     219                  1359           no
# 4    5  Evan  forward     198     223                   362          yes
# 5    6  Fred    guard     166     188                  1536          yes
# 6    7  Gale  forward     195     221                   694           no
# 7    8  Hank    guard     182     199                  1678          yes
# 8    9  Iain    guard     189     199                   385          yes
# 9   10  Jake  forward     205     232                  1416           no
# 10  11  Kyle   center     206     246                   314           no
# 11  12  Lyle    guard     185     207                  1497          yes
# ...

# %%
angela_bb.columns
# Out:
# Index(['ID', 'Name', 'Position', 'Height', 'Weight', 'Sponsorship Earnings',
#        'Shoe Sponsor', 'Career Stage', 'Age'],
#       dtype='object')

# %%
sb.scatterplot(x = 'Height', y = 'Weight', hue = 'Career Stage', data = angela_bb)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>
