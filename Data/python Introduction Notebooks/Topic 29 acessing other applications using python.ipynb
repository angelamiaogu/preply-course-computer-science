# %%
import os
os.system("say what is your name? please write")
x = input("name:")
#os.system("say Mister andy is only 8 years old but he is going to 4th grade")
os.system(f"say hiiiii {x} nice to eat you hoooooooolalalala ")
while(True):
    os.system(f"say hey {x} which website you want to open write only name")
    web = input("website:")
    os.system(f"open http://www.{web}.com/")
    os.system(f"say {web} website opens")

# %%
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 909.1 kB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 3.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.5/120.5 kB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 1.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.7/273.7 kB 2.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 1.0 MB/s eta 0:00:0000:0100:010m
# ...
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.56.0
#     Uninstalling grpcio-1.56.0:
#       Successfully uninstalled grpcio-1.56.0
# ...

# %%
import speech_recognition as sr

def convert_audio_to_text():
    # Create a recognizer object
    recognizer = sr.Recognizer()

    # Use the default microphone as the source
    with sr.Microphone() as source:
        print("Speak something...")
        audio = recognizer.listen(source)

    try:
        # Recognize the audio using Google Web Speech API
        text = recognizer.recognize_google(audio)
        print("You said: " + text)
    except sr.UnknownValueError:
        print("Could not understand audio.")
    except sr.RequestError as e:
        print("Error making the request; {0}".format(e))

if __name__ == "__main__":
    convert_audio_to_text()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/speech_recognition/__init__.py in get_pyaudio()
#     107         try:
# --> 108             import pyaudio
#     109         except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /var/folders/l_/j699flmx6dbc1vlb90jx_hyw0000gn/T/ipykernel_74525/340814539.py in <module>
#      20
#      21 if __name__ == "__main__":
# ---> 22     convert_audio_to_text()
#
# /var/folders/l_/j699flmx6dbc1vlb90jx_hyw0000gn/T/ipykernel_74525/340814539.py in convert_audio_to_text()
#       6
#       7     # Use the default microphone as the source
# ----> 8     with sr.Microphone() as source:
#       9         print("Speak something...")
# ...

# %%
pip install speechrecognition
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.1/737.1 kB 1.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.2/228.2 kB 1.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.5/390.5 kB 1.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 738.1 kB/s eta 0:00:00 0:00:01
# ...
#   Attempting uninstall: pyobjc-core
#     Found existing installation: pyobjc-core 8.5
#     Uninstalling pyobjc-core-8.5:
#       Successfully uninstalled pyobjc-core-8.5
#   Attempting uninstall: pyobjc-framework-Cocoa
#     Found existing installation: pyobjc-framework-Cocoa 8.5
#     Uninstalling pyobjc-framework-Cocoa-8.5:
#       Successfully uninstalled pyobjc-framework-Cocoa-8.5
#   Attempting uninstall: pyobjc-framework-FSEvents
#     Found existing installation: pyobjc-framework-FSEvents 8.5
# ...
