# %%
import pandas as pd
#make a lits of any ten fruits names
x = ("banana", "kiwi", "cherry", "peach", "tomato", "pineapple", "mango", "lychee", "lemon")

     
# make a list of their respective colros
y = ("yellow", 'yellow','red', 'peach', 'red', 'yellow', 'yellow', 'white', 'yellow')

z = (2,4,0.2,5,3,5,7,1,2)#


u = {}
u['fruit'] = x
u['color'] = y
u['price'] =  z

# %%
u
# Out:
# {'fruit': ('banana',
#   'kiwi',
#   'cherry',
#   'peach',
#   'tomato',
#   'pineapple',
#   'mango',
#   'lychee',
#   'lemon'),
#  'color': ('yellow',
#   'yellow',
#   'red',
#   'peach',
#   'red',
#   'yellow',
#   'yellow',
#   'white',
#   'yellow'),
#  'price': (2, 4, 0.2, 5, 3, 5, 7, 1, 2)}

# %%
data = pd.DataFrame(u)

# %%
data['updated_price'] = data['price'] * 1.10

# %%
data
# Out:
#        fruit   color  price  updated_price
# 0     banana  yellow    2.0           2.20
# 1       kiwi  yellow    4.0           4.40
# 2     cherry     red    0.2           0.22
# 3      peach   peach    5.0           5.50
# 4     tomato     red    3.0           3.30
# 5  pineapple  yellow    5.0           5.50
# 6      mango  yellow    7.0           7.70
# 7     lychee   white    1.0           1.10
# 8      lemon  yellow    2.0           2.20

# %%
data['new_price'] = data['price'] * 1.1 * 1.05

# %%
data
# Out:
#        fruit   color  price  updated_price  new_price
# 0     banana  yellow    2.0           2.20      2.310
# 1       kiwi  yellow    4.0           4.40      4.620
# 2     cherry     red    0.2           0.22      0.231
# 3      peach   peach    5.0           5.50      5.775
# 4     tomato     red    3.0           3.30      3.465
# 5  pineapple  yellow    5.0           5.50      5.775
# 6      mango  yellow    7.0           7.70      8.085
# 7     lychee   white    1.0           1.10      1.155
# 8      lemon  yellow    2.0           2.20      2.310

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data = data.set_index("fruit")

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='fruit'>

# %%
data.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='fruit'>

# %%
data.to_csv("data.csv")
