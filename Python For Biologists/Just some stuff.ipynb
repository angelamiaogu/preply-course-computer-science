# %%
file = open('Emails.txt')

# %%
for each in file.readlines():
    if ':' in each.strip() :
        k = each.split(':')
        data2 = k[-1].split(',')
        for i in data2:
            print('§',i )

    else:
        print(each.strip())
# Out:
# § s.hrofficer2@sghemirates.com
# § rec.sup1@sghdubai.com
# § careers@sghdubai.com
# § hrrec3.dxb@saudigerman.com
# § medicalhruae@gmail.com
# § hr@imh.ae
#
# § 𝗞𝗵𝗮𝗹𝗶𝗳𝗮 𝗔𝗷𝗺𝗮𝗻
# § recruitment@skmca.ae
# § recruit2@primesource.ae
# § talentacquisiton@healthpoint.ae
#
# § 𝗛𝗠𝗦 (𝗔𝗜 𝗚𝗔𝗥𝗛𝗢𝗨𝗗)
# § info@hmsco.ae
# § mdrio@hmsco.ae
# § cbelda@hmsco.ae
# § career@hmsco.ae
# § hrd@alhilalms.ae
#
# § 𝗗𝘂𝗯𝗮𝗶 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹
# § MABHafedh@dha.gov.ae
# § EMMAALI@dha.gov.ae
# § yabdulrahman@dha.gov.ac
# § MABHafedh@dha.gov.ae
#
# § 𝗠𝗲𝗱𝗶𝗰𝗹𝗶𝗻𝗶𝗰 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹𝘀
# § Ramya.Halbhavi@mediclinic.ae
# § neeren.arcega@uhs.ae
# § Charina.Panganiban@mediclinic.ae
# § Gretchen.Bernardino@mediclinic.ae
# § maria.orilla@healthtalentconsulting.com
#
# § 𝗖𝗮𝗻𝗮𝗱𝗶𝗮𝗻 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹
# § M.asghar@csh.ae
# § careers@csh.ae
#
# § 𝗚𝗮𝗿𝗴𝗮𝘀𝗵 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹
# § jithikajayan@gmail.com
# § info@gargashhospital.com
#
# § 𝗙𝗮𝗸𝗲𝗲𝗵 𝗛𝗼𝘀𝗽𝗶𝘁𝗮𝗹
# § recruit2@primesource.ae
# § hr.dubai@fakech.care
# § fbbonni@fakeeh.care
# § drfameg@yahoo.com
# § fgul@fakech.care
# ...
