# %%
# import files

# %%
import pandas as pd

# %%
data = pd.read_csv("1000_cryptos.csv")
data
# Out:
#          Unnamed: 0        Date      Open      High       Low     Close  \
# 0                 0  2023-06-13  0.200132  0.202672  0.197668  0.199337
# 1                 1  2023-06-14  0.199333  0.202175  0.195464  0.196212
# 2                 2  2023-06-15  0.196201  0.199728  0.195101  0.198773
# 3                 3  2023-06-16  0.198772  0.205611  0.196799  0.202320
# 4                 4  2023-06-17  0.202321  0.206999  0.201455  0.206174
# ...             ...         ...       ...       ...       ...       ...
# 1119094     1119094  2024-06-02  0.020457  0.020534  0.019948  0.020347
# 1119095     1119095  2024-06-03  0.020347  0.021529  0.020209  0.021376
# 1119096     1119096  2024-06-04  0.021376  0.021990  0.021301  0.021921
# 1119097     1119097  2024-06-05  0.021921  0.022335  0.021342  0.022328
# 1119098     1119098  2024-06-06  0.022328  0.022372  0.021755  0.021931
#
#          Adj Close    Volume   Symbol
# 0         0.199337  246568.0  BTC-USD
# ...

# %%
data.columns # whare are these??
# Out:
# Index(['Unnamed: 0', 'Date', 'Open', 'High', 'Low', 'Close', 'Adj Close',
#        'Volume', 'Symbol'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Sample data
data = data.iloc[-100:,:]
# Convert dates to a format that matplotlib can handle
dates = data.Date
open_price = data.Open
close_price = data.Close

plt.figure(figsize=(10, 5))
plt.plot(dates, open_price, label='Open Prices', marker='o')
plt.plot(dates, close_price, label='Close Prices', marker='x')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Open and Close Prices')
plt.legend()
plt.grid(True)
# rotate y label  90 degree
plt.xticks(rotation=90)
plt.show()
